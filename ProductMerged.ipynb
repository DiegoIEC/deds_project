# %%
import pandas as pd 
import pyodbc
import warnings
warnings.simplefilter('ignore')
import sqlite3

# %% [markdown]
# Connection with Outdoors

# %%
DB = {
    'servername': 'tcp:dwhunitedoutdoors.database.windows.net,1433',
    'database': 'DWH_United_Outdoors',
    'username': 'onderzoeker',
    'password': 'Wachtwoord1.' 
}

conn_str = (
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=' + DB['servername'] + ';'
    'DATABASE=' + DB['database'] + ';'
    'UID=' + DB['username'] + ';'
    'PWD=' + DB['password'] + ';'
    'Encrypt=yes;'
    'TrustServerCertificate=no;'
    'Connection Timeout=30;'
)

export_conn = pyodbc.connect(conn_str)
export_cursor = export_conn.cursor()
export_cursor

# %%
DB_AW = {'servername': 'TROYK\\SQLEXPRESS',
'database': 'AdventureWorks2019'}

DB_AW_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=' + DB_AW['servername'] +
                              ';DATABASE=' + DB_AW['database'] + ';Trusted_Connection=yes')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 4
#       1 DB_AW = {'servername': 'TROYK\\SQLEXPRESS',
#       2 'database': 'AdventureWorks2019'}
# ----> 4 DB_AW_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=' + DB_AW['servername'] +
#       5                               ';DATABASE=' + DB_AW['database'] + ';Trusted_Connection=yes')
#
# ProgrammingError: ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Cannot open database "AdventureWorks2019" requested by the login. The login failed. (4060) (SQLDriverConnect); [42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Cannot open database "AdventureWorks2019" requested by the login. The login failed. (4060)')

# %% [markdown]
# Connection with northwind

# %%
DB = {'servername': 'TROYK\SQLEXPRESS',
'database': 'Northwind'}

DB_NW_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=' + DB['servername'] +
                             ';DATABASE=' + DB['database'] + ';Trusted_Connection=yes')
export_cursor = export_conn.cursor()
export_cursor

# %% [markdown]
# Customer table in dataframe van northwind

# %%
query_customers = "SELECT * FROM Customers"

# Execute the query and load data into a Pandas DataFrame
customers_df = pd.read_sql(query_customers, DB_NW_conn)

# Close the database connection

# Now you have the Customers table in a Pandas DataFrame
print(customers_df.head())  # Display the first few rows to verify
# Out:
#   CustomerID                         CompanyName         ContactName  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                  Berglunds snabbköp  Christina Berglund
#
#            ContactTitle                        Address         City Region  \
# 0  Sales Representative                  Obere Str. 57       Berlin   None
# 1                 Owner  Avda. de la Constitución 2222  México D.F.   None
# 2                 Owner                Mataderos  2312  México D.F.   None
# 3  Sales Representative                120 Hanover Sq.       London   None
# 4   Order Administrator                Berguvsvägen  8        Luleå   None
#
#   PostalCode  Country           Phone             Fax
# 0      12209  Germany     030-0074321     030-0076545
# 1      05021   Mexico    (5) 555-4729    (5) 555-3745
# 2      05023   Mexico    (5) 555-3932            None
# 3    WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# 4   S-958 22   Sweden   0921-12 34 65   0921-12 34 67

# %% [markdown]
# Product table van AW in dataframe

# %%
query_product = "SELECT * FROM Production.Product"

# Execute the query and load data into a Pandas DataFrame
product_df = pd.read_sql(query_product, DB_AW_conn)

# Close the database connection

# Now you have the Product table in a Pandas DataFrame
product_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 query_product = "SELECT * FROM Production.Product"
#       3 # Execute the query and load data into a Pandas DataFrame
# ----> 4 product_df = pd.read_sql(query_product, DB_AW_conn)
#       6 # Close the database connection
#       7
#       8 # Now you have the Product table in a Pandas DataFrame
#       9 product_df
#
# NameError: name 'DB_AW_conn' is not defined

# %% [markdown]
# Product table van NW in dataframe

# %%
queryProductss = "SELECT * FROM Products"

# Execute the query and load data into a Pandas DataFrame
Productss_df = pd.read_sql(queryProductss, DB_NW_conn)

# Close the database connection

# Now you have the Customers table in a Pandas DataFrame
# print(Productss_df.head())  # Display the first few rows to verify
Productss_df
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#         QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0    10 boxes x 20 bags      18.00            39             0            10
# 1    24 - 12 oz bottles      19.00            17            40            25
# 2   12 - 550 ml bottles      10.00            13            70            25
# 3        48 - 6 oz jars      22.00            53             0             0
# 4              36 boxes      21.35             0             0             0
# ..                  ...        ...           ...           ...           ...
# 72      24 - 150 g jars      15.00           101             0             5
# 73            5 kg pkg.      10.00             4            20             5
# 74   24 - 0.5 l bottles       7.75           125             0            25
# 75               500 ml      18.00            57             0            20
# 76             12 boxes      13.00            32             0            15
#
#     Discontinued
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True
# ..           ...
# 72         False
# 73         False
# 74         False
# 75         False
# 76         False
#
# [77 rows x 10 columns]

# %% [markdown]
# Product table van AENC

# %% [markdown]
# Merge Product

# %%
product_df['ProductID'] += Productss_df['ProductID'].max() + 1

# Merge the DataFrames into one combined DataFrame
combined_product_df = pd.concat([product_df, Productss_df], ignore_index=True)

combined_product_df
# Out:
#      ProductID                   Name ProductNumber MakeFlag  \
# 0           79        Adjustable Race       AR-5381    False
# 1           80           Bearing Ball       BA-8327    False
# 2           81        BB Ball Bearing       BE-2349     True
# 3           82  Headset Ball Bearings       BE-2908    False
# 4          394                  Blade       BL-2036     True
# ..         ...                    ...           ...      ...
# 576         73                    NaN           NaN      NaN
# 577         74                    NaN           NaN      NaN
# 578         75                    NaN           NaN      NaN
# 579         76                    NaN           NaN      NaN
# 580         77                    NaN           NaN      NaN
#
#     FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0               False  None            1000.0         750.0           0.0
# 1               False  None            1000.0         750.0           0.0
# 2               False  None             800.0         600.0           0.0
# 3               False  None             800.0         600.0           0.0
# 4               False  None             800.0         600.0           0.0
# ..                ...   ...               ...           ...           ...
# 576               NaN   NaN               NaN           NaN           NaN
# 577               NaN   NaN               NaN           NaN           NaN
# 578               NaN   NaN               NaN           NaN           NaN
# 579               NaN   NaN               NaN           NaN           NaN
# 580               NaN   NaN               NaN           NaN           NaN
#
#      ListPrice  ...            ModifiedDate                      ProductName  \
# 0          0.0  ... 2014-02-08 10:01:36.827                              NaN
# 1          0.0  ... 2014-02-08 10:01:36.827                              NaN
# 2          0.0  ... 2014-02-08 10:01:36.827                              NaN
# 3          0.0  ... 2014-02-08 10:01:36.827                              NaN
# 4          0.0  ... 2014-02-08 10:01:36.827                              NaN
# ..         ...  ...                     ...                              ...
# 576        NaN  ...                     NaT                       Röd Kaviar
# 577        NaN  ...                     NaT                    Longlife Tofu
# 578        NaN  ...                     NaT             Rhönbräu Klosterbier
# 579        NaN  ...                     NaT                     Lakkalikööri
# 580        NaN  ...                     NaT  Original Frankfurter grüne Soße
#
#     SupplierID  CategoryID     QuantityPerUnit UnitPrice UnitsInStock  \
# 0          NaN         NaN                 NaN       NaN          NaN
# 1          NaN         NaN                 NaN       NaN          NaN
# 2          NaN         NaN                 NaN       NaN          NaN
# 3          NaN         NaN                 NaN       NaN          NaN
# 4          NaN         NaN                 NaN       NaN          NaN
# ..         ...         ...                 ...       ...          ...
# 576       17.0         8.0     24 - 150 g jars     15.00        101.0
# 577        4.0         7.0           5 kg pkg.     10.00          4.0
# 578       12.0         1.0  24 - 0.5 l bottles      7.75        125.0
# 579       23.0         1.0              500 ml     18.00         57.0
# 580       12.0         2.0            12 boxes     13.00         32.0
#
#     UnitsOnOrder  ReorderLevel  Discontinued
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# ..           ...           ...           ...
# 576          0.0           5.0         False
# 577         20.0           5.0         False
# 578          0.0          25.0         False
# 579          0.0          20.0         False
# 580          0.0          15.0         False
#
# [581 rows x 34 columns]

# %% [markdown]
# import PRODUCT INTO DATAWAREHOUSE

# %%
def insert_into_combined_product(combined_product_df, export_conn):
    try:
        export_cursor = export_conn.cursor()

        # Create the Combined_Product table if it does not exist
        create_table_query = """
        IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='Combined_Product' AND xtype='U')
        CREATE TABLE Combined_Product (
            ProductID INT,
            Name NVARCHAR(255),
            ProductNumber NVARCHAR(25),
            MakeFlag BIT,
            FinishedGoodsFlag BIT,
            Color NVARCHAR(15),
            SafetyStockLevel SMALLINT,
            ReorderPoint SMALLINT,
            StandardCost DECIMAL(19, 4),
            ListPrice DECIMAL(19, 4),
            ModifiedDate DATETIME,
            ProductName NVARCHAR(255),
            SupplierID INT,
            CategoryID INT,
            QuantityPerUnit NVARCHAR(50),
            UnitPrice DECIMAL(19, 4),
            UnitsInStock SMALLINT,
            UnitsOnOrder SMALLINT,
            ReorderLevel SMALLINT,
            Discontinued BIT
        )
        """
        export_cursor.execute(create_table_query)

        # Insert rows into the Combined_Product table
        for index, row in combined_product_df.iterrows():
            try:
                query = f"""
                INSERT INTO Combined_Product (
                    ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
                    SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
                    ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
                    UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
                ) VALUES (
                    {row['ProductID'] if row['ProductID'] is not None else 'NULL'},
                    '{str(row['Name']).replace("'", "''") if row['Name'] is not None else 'NULL'}',
                    '{str(row['ProductNumber']).replace("'", "''") if row['ProductNumber'] is not None else 'NULL'}',
                    {1 if row['MakeFlag'] else 0},
                    {1 if row['FinishedGoodsFlag'] else 0},
                    '{str(row['Color']).replace("'", "''") if row['Color'] is not None else 'NULL'}',
                    {row['SafetyStockLevel'] if row['SafetyStockLevel'] is not None else 'NULL'},
                    {row['ReorderPoint'] if row['ReorderPoint'] is not None else 'NULL'},
                    {row['StandardCost'] if row['StandardCost'] is not None else 'NULL'},
                    {row['ListPrice'] if row['ListPrice'] is not None else 'NULL'},
                    '{row['ModifiedDate']}' if row['ModifiedDate'] is not None else 'NULL',
                    '{str(row['ProductName']).replace("'", "''") if row['ProductName'] is not None else 'NULL'}',
                    {row['SupplierID'] if row['SupplierID'] is not None else 'NULL'},
                    {row['CategoryID'] if row['CategoryID'] is not None else 'NULL'},
                    '{str(row['QuantityPerUnit']).replace("'", "''") if row['QuantityPerUnit'] is not None else 'NULL'}',
                    {row['UnitPrice'] if row['UnitPrice'] is not None else 'NULL'},
                    {row['UnitsInStock'] if row['UnitsInStock'] is not None else 'NULL'},
                    {row['UnitsOnOrder'] if row['UnitsOnOrder'] is not None else 'NULL'},
                    {row['ReorderLevel'] if row['ReorderLevel'] is not None else 'NULL'},
                    {1 if row['Discontinued'] else 0}
                )
                """
                export_cursor.execute(query)
            except pyodbc.Error as e:
                print("Error:", e)
                print("Query:", query)

        export_conn.commit()
    except pyodbc.Error as e:
        print("Error:", e)
    finally:
        export_cursor.close()

insert_into_combined_product(combined_product_df,export_conn)
# Out:
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     79,
#                     'Adjustable Race',
#                     'AR-5381',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     80,
#                     'Bearing Ball',
#                     'BA-8327',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     81,
#                     'BB Ball Bearing',
#                     'BE-2349',
#                     1,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     82,
#                     'Headset Ball Bearings',
#                     'BE-2908',
#                     0,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     394,
#                     'Blade',
#                     'BL-2036',
#                     1,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     395,
#                     'LL Crankarm',
#                     'CA-5965',
#                     0,
#                     0,
#                     'Black',
#                     500.0,
#                     375.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     396,
#                     'ML Crankarm',
#                     'CA-6738',
#                     0,
#                     0,
#                     'Black',
#                     500.0,
#                     375.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     397,
#                     'HL Crankarm',
#                     'CA-7457',
#                     0,
#                     0,
#                     'Black',
#                     500.0,
#                     375.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     398,
#                     'Chainring Bolts',
#                     'CB-2903',
#                     0,
#                     0,
#                     'Silver',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     399,
#                     'Chainring Nut',
#                     'CN-6137',
#                     0,
#                     0,
#                     'Silver',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     400,
#                     'Chainring',
#                     'CR-7833',
#                     0,
#                     0,
#                     'Black',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     401,
#                     'Crown Race',
#                     'CR-9981',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     402,
#                     'Chain Stays',
#                     'CS-2812',
#                     1,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     403,
#                     'Decal 1',
#                     'DC-8732',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     404,
#                     'Decal 2',
#                     'DC-9824',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     405,
#                     'Down Tube',
#                     'DT-2377',
#                     1,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     406,
#                     'Mountain End Caps',
#                     'EC-M092',
#                     1,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     407,
#                     'Road End Caps',
#                     'EC-R098',
#                     1,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     408,
#                     'Touring End Caps',
#                     'EC-T209',
#                     1,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     409,
#                     'Fork End',
#                     'FE-3760',
#                     1,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     410,
#                     'Freewheel',
#                     'FH-2981',
#                     0,
#                     0,
#                     'Silver',
#                     500.0,
#                     375.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     419,
#                     'Flat Washer 1',
#                     'FW-1000',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     420,
#                     'Flat Washer 6',
#                     'FW-1200',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     421,
#                     'Flat Washer 2',
#                     'FW-1400',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     422,
#                     'Flat Washer 9',
#                     'FW-3400',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     423,
#                     'Flat Washer 4',
#                     'FW-3800',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     424,
#                     'Flat Washer 3',
#                     'FW-5160',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     425,
#                     'Flat Washer 8',
#                     'FW-5800',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     426,
#                     'Flat Washer 5',
#                     'FW-7160',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     427,
#                     'Flat Washer 7',
#                     'FW-9160',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     428,
#                     'Fork Crown',
#                     'FC-3654',
#                     1,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     429,
#                     'Front Derailleur Cage',
#                     'FC-3982',
#                     0,
#                     0,
#                     'Silver',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     430,
#                     'Front Derailleur Linkage',
#                     'FL-2301',
#                     0,
#                     0,
#                     'Silver',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     433,
#                     'Guide Pulley',
#                     'GP-0982',
#                     0,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     434,
#                     'LL Grip Tape',
#                     'GT-0820',
#                     0,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     435,
#                     'ML Grip Tape',
#                     'GT-1209',
#                     0,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     436,
#                     'HL Grip Tape',
#                     'GT-2908',
#                     0,
#                     0,
#                     'NULL',
#                     800.0,
#                     600.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     437,
#                     'Thin-Jam Hex Nut 9',
#                     'HJ-1213',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     438,
#                     'Thin-Jam Hex Nut 10',
#                     'HJ-1220',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     439,
#                     'Thin-Jam Hex Nut 1',
#                     'HJ-1420',
#                     0,
#                     0,
#                     'NULL',
#                     1000.0,
#                     750.0,
#                     0.0,
#                     0.0,
#                     '2014-02-08 10:01:36.827000' if row['ModifiedDate'] is not None else 'NULL',
#                     'nan',
#                     nan,
#                     nan,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     1
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
# ...
#                     64,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Wimmers gute Semmelknödel',
#                     12.0,
#                     5.0,
#                     '20 bags x 4 pieces',
#                     33.25,
#                     22.0,
#                     80.0,
#                     30.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     65,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Louisiana Fiery Hot Pepper Sauce',
#                     2.0,
#                     2.0,
#                     '32 - 8 oz bottles',
#                     21.05,
#                     76.0,
#                     0.0,
#                     0.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     66,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Louisiana Hot Spiced Okra',
#                     2.0,
#                     2.0,
#                     '24 - 8 oz jars',
#                     17.0,
#                     4.0,
#                     100.0,
#                     20.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     67,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Laughing Lumberjack Lager',
#                     16.0,
#                     1.0,
#                     '24 - 12 oz bottles',
#                     14.0,
#                     52.0,
#                     0.0,
#                     10.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     68,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Scottish Longbreads',
#                     8.0,
#                     3.0,
#                     '10 boxes x 8 pieces',
#                     12.5,
#                     6.0,
#                     10.0,
#                     15.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     69,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Gudbrandsdalsost',
#                     15.0,
#                     4.0,
#                     '10 kg pkg.',
#                     36.0,
#                     26.0,
#                     0.0,
#                     15.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     70,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Outback Lager',
#                     7.0,
#                     1.0,
#                     '24 - 355 ml bottles',
#                     15.0,
#                     15.0,
#                     10.0,
#                     30.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     71,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Flotemysost',
#                     15.0,
#                     4.0,
#                     '10 - 500 g pkgs.',
#                     21.5,
#                     26.0,
#                     0.0,
#                     0.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     72,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Mozzarella di Giovanni',
#                     14.0,
#                     4.0,
#                     '24 - 200 g pkgs.',
#                     34.8,
#                     14.0,
#                     0.0,
#                     0.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     73,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Röd Kaviar',
#                     17.0,
#                     8.0,
#                     '24 - 150 g jars',
#                     15.0,
#                     101.0,
#                     0.0,
#                     5.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     74,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Longlife Tofu',
#                     4.0,
#                     7.0,
#                     '5 kg pkg.',
#                     10.0,
#                     4.0,
#                     20.0,
#                     5.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     75,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Rhönbräu Klosterbier',
#                     12.0,
#                     1.0,
#                     '24 - 0.5 l bottles',
#                     7.75,
#                     125.0,
#                     0.0,
#                     25.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     76,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Lakkalikööri',
#                     23.0,
#                     1.0,
#                     '500 ml',
#                     18.0,
#                     57.0,
#                     0.0,
#                     20.0,
#                     0
#                 )
#
# Error: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'if'. (156) (SQLExecDirectW)")
# Query:
#                 INSERT INTO Combined_Product (
#                     ProductID, Name, ProductNumber, MakeFlag, FinishedGoodsFlag, Color,
#                     SafetyStockLevel, ReorderPoint, StandardCost, ListPrice, ModifiedDate,
#                     ProductName, SupplierID, CategoryID, QuantityPerUnit, UnitPrice,
#                     UnitsInStock, UnitsOnOrder, ReorderLevel, Discontinued
#                 ) VALUES (
#                     77,
#                     'nan',
#                     'nan',
#                     1,
#                     1,
#                     'nan',
#                     nan,
#                     nan,
#                     nan,
#                     nan,
#                     'NaT' if row['ModifiedDate'] is not None else 'NULL',
#                     'Original Frankfurter grüne Soße',
#                     12.0,
#                     2.0,
#                     '12 boxes',
#                     13.0,
#                     32.0,
#                     0.0,
#                     15.0,
#                     0
#                 )

# %% [markdown]
# CUSTOMER TABLE FROM AW IN DATAFRAME
#
# SAles terrirtory mergerd with customer table

# %%
queryCUSTOMERAW = "SELECT * FROM SALES.CUSTOMER"
queryTERITORY= "SELECT * FROM SALES.SalesTerritory"
Teritory_df= pd.read_sql(queryTERITORY,DB_AW_conn)
# Execute the query and load data into a Pandas DataFrame
CUSTOMERSAW_DF = pd.read_sql(queryCUSTOMERAW, DB_AW_conn)

# Close the database connection

# Now you have the Product table in a Pandas DataFrame
# CUSTOMERSAW_DF
# Teritory_df
merged_df = pd.merge(CUSTOMERSAW_DF, Teritory_df, on='TerritoryID', suffixes=('_Customer', '_Territory'))
merged_df
# Out:
#        CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0               1       NaN    934.0            1    AW00000001
# 1               2       NaN   1028.0            1    AW00000002
# 2               3       NaN    642.0            4    AW00000003
# 3               4       NaN    932.0            4    AW00000004
# 4               5       NaN   1026.0            4    AW00000005
# ...           ...       ...      ...          ...           ...
# 19815       30114    1985.0   1986.0            7    AW00030114
# 19816       30115    1987.0   1988.0            6    AW00030115
# 19817       30116    1989.0   1990.0            4    AW00030116
# 19818       30117    1991.0   1992.0            4    AW00030117
# 19819       30118    1993.0   1994.0            3    AW00030118
#
#                            rowguid_Customer   ModifiedDate_Customer  \
# 0      3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 1      E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 2      130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 3      FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 4      83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# ...                                     ...                     ...
# 19815  97154F3D-28F1-4B15-AE03-9518B781ECE3 2014-09-12 11:15:07.263
# 19816  E4CF8FD5-30A4-4B8E-8FD8-47032E255778 2014-09-12 11:15:07.263
# 19817  EC409609-D25D-41B8-9D15-A1AA6E89FC77 2014-09-12 11:15:07.263
# 19818  6F08E2FB-1CD3-4F6E-A2E6-385669598B19 2014-09-12 11:15:07.263
# 19819  2495B4EB-FE8B-459E-A1B6-DBA25C04E626 2014-09-12 11:15:07.263
#
#             Name CountryRegionCode          Group      SalesYTD  \
# 0      Northwest                US  North America  7.887187e+06
# 1      Northwest                US  North America  7.887187e+06
# 2      Southwest                US  North America  1.051085e+07
# 3      Southwest                US  North America  1.051085e+07
# 4      Southwest                US  North America  1.051085e+07
# ...          ...               ...            ...           ...
# 19815     France                FR         Europe  4.772398e+06
# 19816     Canada                CA  North America  6.771829e+06
# 19817  Southwest                US  North America  1.051085e+07
# 19818  Southwest                US  North America  1.051085e+07
# 19819    Central                US  North America  3.072175e+06
#
#        SalesLastYear  CostYTD  CostLastYear  \
# 0       3.298694e+06      0.0           0.0
# 1       3.298694e+06      0.0           0.0
# 2       5.366576e+06      0.0           0.0
# 3       5.366576e+06      0.0           0.0
# 4       5.366576e+06      0.0           0.0
# ...              ...      ...           ...
# 19815   2.396540e+06      0.0           0.0
# 19816   5.693989e+06      0.0           0.0
# 19817   5.366576e+06      0.0           0.0
# 19818   5.366576e+06      0.0           0.0
# 19819   3.205014e+06      0.0           0.0
#
#                           rowguid_Territory ModifiedDate_Territory
# 0      43689A10-E30B-497F-B0DE-11DE20267FF7             2008-04-30
# 1      43689A10-E30B-497F-B0DE-11DE20267FF7             2008-04-30
# 2      DC3E9EA0-7950-4431-9428-99DBCBC33865             2008-04-30
# 3      DC3E9EA0-7950-4431-9428-99DBCBC33865             2008-04-30
# 4      DC3E9EA0-7950-4431-9428-99DBCBC33865             2008-04-30
# ...                                     ...                    ...
# 19815  BF806804-9B4C-4B07-9D19-706F2E689552             2008-04-30
# 19816  06B4AF8A-1639-476E-9266-110461D66B00             2008-04-30
# 19817  DC3E9EA0-7950-4431-9428-99DBCBC33865             2008-04-30
# 19818  DC3E9EA0-7950-4431-9428-99DBCBC33865             2008-04-30
# 19819  DF6E7FD8-1A8D-468C-B103-ED8ADDB452C1             2008-04-30
#
# [19820 rows x 16 columns]

# %% [markdown]
# CUSTOMER TABLE FROM NW IN DATAFRAME

# %%
queryCUSTOMERSNW = "SELECT * FROM Customers"

# Execute the query and load data into a Pandas DataFrame
CustomersNW_df = pd.read_sql(queryCUSTOMERSNW, DB_NW_conn)

# Close the database connection

# Now you have the Customers table in a Pandas DataFrame
# print(Productss_df.head())  # Display the first few rows to verify
CustomersNW_df
# Out:
#    CustomerID                         CompanyName              ContactName  \
# 0       ALFKI                 Alfreds Futterkiste             Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2       ANTON             Antonio Moreno Taquería           Antonio Moreno
# 3       AROUT                     Around the Horn             Thomas Hardy
# 4       BERGS                  Berglunds snabbköp       Christina Berglund
# ..        ...                                 ...                      ...
# 86      WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87      WELLI              Wellington Importadora            Paula Parente
# 88      WHITC                White Clover Markets           Karl Jablonski
# 89      WILMK                         Wilman Kala          Matti Karttunen
# 90      WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                  ContactTitle                        Address         City  \
# 0        Sales Representative                  Obere Str. 57       Berlin
# 1                       Owner  Avda. de la Constitución 2222  México D.F.
# 2                       Owner                Mataderos  2312  México D.F.
# 3        Sales Representative                120 Hanover Sq.       London
# 4         Order Administrator                Berguvsvägen  8        Luleå
# ..                        ...                            ...          ...
# 86         Accounting Manager                    Torikatu 38         Oulu
# 87              Sales Manager             Rua do Mercado, 12      Resende
# 88                      Owner    305 - 14th Ave. S. Suite 3B      Seattle
# 89  Owner/Marketing Assistant                  Keskuskatu 45     Helsinki
# 90                      Owner                ul. Filtrowa 68     Warszawa
#
#    Region PostalCode  Country           Phone             Fax
# 0    None      12209  Germany     030-0074321     030-0076545
# 1    None      05021   Mexico    (5) 555-4729    (5) 555-3745
# 2    None      05023   Mexico    (5) 555-3932            None
# 3    None    WA1 1DP       UK  (171) 555-7788  (171) 555-6750
# 4    None   S-958 22   Sweden   0921-12 34 65   0921-12 34 67
# ..    ...        ...      ...             ...             ...
# 86   None      90110  Finland      981-443655      981-443655
# 87     SP  08737-363   Brazil   (14) 555-8122            None
# 88     WA      98128      USA  (206) 555-4112  (206) 555-4115
# 89   None      21240  Finland     90-224 8858     90-224 8858
# 90   None     01-012   Poland   (26) 642-7012   (26) 642-7012
#
# [91 rows x 11 columns]

# %% [markdown]
# MERGE CUSTOMER TABLES From AW & NW

# %%
merged_df['CustomerID'] = merged_df['CustomerID'].astype(str)

# Convert CustomerID to string/object type in CustomersNW_df
CustomersNW_df['CustomerID'] = CustomersNW_df['CustomerID'].astype(str)
finalMergedCUstomers_df= pd.merge(merged_df, CustomersNW_df, on='CustomerID', how='left')

finalMergedCUstomers_df
# Out:
#       CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0              1       NaN    934.0            1    AW00000001
# 1              2       NaN   1028.0            1    AW00000002
# 2              3       NaN    642.0            4    AW00000003
# 3              4       NaN    932.0            4    AW00000004
# 4              5       NaN   1026.0            4    AW00000005
# ...          ...       ...      ...          ...           ...
# 19815      30114    1985.0   1986.0            7    AW00030114
# 19816      30115    1987.0   1988.0            6    AW00030115
# 19817      30116    1989.0   1990.0            4    AW00030116
# 19818      30117    1991.0   1992.0            4    AW00030117
# 19819      30118    1993.0   1994.0            3    AW00030118
#
#                            rowguid_Customer   ModifiedDate_Customer  \
# 0      3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 1      E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 2      130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 3      FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 4      83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# ...                                     ...                     ...
# 19815  97154F3D-28F1-4B15-AE03-9518B781ECE3 2014-09-12 11:15:07.263
# 19816  E4CF8FD5-30A4-4B8E-8FD8-47032E255778 2014-09-12 11:15:07.263
# 19817  EC409609-D25D-41B8-9D15-A1AA6E89FC77 2014-09-12 11:15:07.263
# 19818  6F08E2FB-1CD3-4F6E-A2E6-385669598B19 2014-09-12 11:15:07.263
# 19819  2495B4EB-FE8B-459E-A1B6-DBA25C04E626 2014-09-12 11:15:07.263
#
#             Name CountryRegionCode          Group  ...  CompanyName  \
# 0      Northwest                US  North America  ...          NaN
# 1      Northwest                US  North America  ...          NaN
# 2      Southwest                US  North America  ...          NaN
# 3      Southwest                US  North America  ...          NaN
# 4      Southwest                US  North America  ...          NaN
# ...          ...               ...            ...  ...          ...
# 19815     France                FR         Europe  ...          NaN
# 19816     Canada                CA  North America  ...          NaN
# 19817  Southwest                US  North America  ...          NaN
# 19818  Southwest                US  North America  ...          NaN
# 19819    Central                US  North America  ...          NaN
#
#        ContactName  ContactTitle  Address City Region PostalCode Country  \
# 0              NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 1              NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 2              NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 3              NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 4              NaN           NaN      NaN  NaN    NaN        NaN     NaN
# ...            ...           ...      ...  ...    ...        ...     ...
# 19815          NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 19816          NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 19817          NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 19818          NaN           NaN      NaN  NaN    NaN        NaN     NaN
# 19819          NaN           NaN      NaN  NaN    NaN        NaN     NaN
#
#       Phone  Fax
# 0       NaN  NaN
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN
# ...     ...  ...
# 19815   NaN  NaN
# 19816   NaN  NaN
# 19817   NaN  NaN
# 19818   NaN  NaN
# 19819   NaN  NaN
#
# [19820 rows x 26 columns]

# %% [markdown]
# customer tabel in datawarehouse importeren

# %%
def insert_into_final_merged_customers(finalMergedCUstomers_df, export_conn):
    try:
        export_cursor = export_conn.cursor()

        # Define the CREATE TABLE query
        create_table_query = """
        IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='final_merged_customers' AND xtype='U')
        CREATE TABLE final_merged_customers (
            CustomerID VARCHAR(50),
            PersonID INT,
            StoreID INT,
            TerritoryID INT,
            AccountNumber VARCHAR(50),
            rowguid_Customer VARCHAR(50),
            ModifiedDate_Customer DATETIME,
            Name VARCHAR(255),
            CountryRegionCode VARCHAR(10),
            "Group" VARCHAR(50),
            -- Add more columns as needed
            CompanyName NVARCHAR(255),
            ContactName NVARCHAR(255),
            ContactTitle NVARCHAR(255),
            Address NVARCHAR(255),
            City NVARCHAR(255),
            Region NVARCHAR(255),
            PostalCode NVARCHAR(50),
            Country NVARCHAR(50),
            Phone NVARCHAR(50),
            Fax NVARCHAR(50)
        )
        """
        export_cursor.execute(create_table_query)
        
        # Iterate through each row in finalMergedCustomers_df and insert into the database
        for index, row in finalMergedCUstomers_df.iterrows():
            try:
                query = f"""
                INSERT INTO final_merged_customers (
                    CustomerID, PersonID, StoreID, TerritoryID, AccountNumber,
                    rowguid_Customer, ModifiedDate_Customer, Name, CountryRegionCode,
                    "Group", CompanyName, ContactName, ContactTitle, Address, City,
                    Region, PostalCode, Country, Phone, Fax
                ) 
                VALUES (
                    '{str(row['CustomerID']).replace("'", "''") if row['CustomerID'] is not None else 'NULL'}',
                    {row['PersonID'] if pd.notnull(row['PersonID']) else 'NULL'},
                    {row['StoreID'] if pd.notnull(row['StoreID']) else 'NULL'},
                    {row['TerritoryID'] if pd.notnull(row['TerritoryID']) else 'NULL'},
                    '{str(row['AccountNumber']).replace("'", "''") if row['AccountNumber'] is not None else 'NULL'}',
                    '{str(row['rowguid_Customer']).replace("'", "''") if row['rowguid_Customer'] is not None else 'NULL'}',
                    '{row['ModifiedDate_Customer'].strftime('%Y-%m-%d %H:%M:%S') if pd.notnull(row['ModifiedDate_Customer']) else 'NULL'}',
                    '{str(row['Name']).replace("'", "''") if row['Name'] is not None else 'NULL'}',
                    '{str(row['CountryRegionCode']).replace("'", "''") if row['CountryRegionCode'] is not None else 'NULL'}',
                    '{str(row['Group']).replace("'", "''") if row['Group'] is not None else 'NULL'}',
                    '{str(row['CompanyName']).replace("'", "''") if row['CompanyName'] is not None else 'NULL'}',
                    '{str(row['ContactName']).replace("'", "''") if row['ContactName'] is not None else 'NULL'}',
                    '{str(row['ContactTitle']).replace("'", "''") if row['ContactTitle'] is not None else 'NULL'}',
                    '{str(row['Address']).replace("'", "''") if row['Address'] is not None else 'NULL'}',
                    '{str(row['City']).replace("'", "''") if row['City'] is not None else 'NULL'}',
                    '{str(row['Region']).replace("'", "''") if row['Region'] is not None else 'NULL'}',
                    '{str(row['PostalCode']).replace("'", "''") if row['PostalCode'] is not None else 'NULL'}',
                    '{str(row['Country']).replace("'", "''") if row['Country'] is not None else 'NULL'}',
                    '{str(row['Phone']).replace("'", "''") if row['Phone'] is not None else 'NULL'}',
                    '{str(row['Fax']).replace("'", "''") if row['Fax'] is not None else 'NULL'}'
                )
                """
                export_cursor.execute(query)
            except pyodbc.Error as e:
                print("Error:", e)
                print("Query:", query)

        export_conn.commit()
        print("Data successfully inserted into final_merged_customers table.")
    except pyodbc.Error as e:
        print("Error:", e)
    finally:
        export_cursor.close()

# Assuming finalMergedCustomers_df is already defined and export_conn is your pyodbc connection
insert_into_final_merged_customers(finalMergedCUstomers_df, export_conn)

# %% [markdown]
# Merge employees table with employee territories and territorie

# %%
queryEmployees = "SELECT * FROM Employees"

# Execute the query and load data into a Pandas DataFrame
employeesNW_df = pd.read_sql(queryEmployees, DB_NW_conn)
employeesAW_df = pd.read_sql(queryEmployees, DB_AW_conn)


queryTerritory= "SELECT * FROM EmployeeTerritories"
territoryNW_DF= pd.read_sql(queryTerritory, DB_NW_conn)

queryEndTErritory= "SELECT * FROM Territories"
FinalTerritory_df= pd.read_sql(queryEndTErritory, DB_NW_conn)


# employees_df = pd.read_sql_query("SELECT * FROM Employees", DB_NW_conn)
# employee_territories_df = pd.read_sql_query("SELECT * FROM EmployeeTerritories", DB_NW_conn)
# territories_df = pd.read_sql_query("SELECT * FROM Territories", DB_NW_conn)
employeesAW_df
# territoryNW_DF
# FinalTerritory_df
# merged_df = employeesNW_df.merge(territoryNW_DF, on='EmployeeID')
# merged_df = merged_df.merge(FinalTerritory_df, on='TerritoryID')

# merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 # Execute the query and load data into a Pandas DataFrame
#       4 employeesNW_df = pd.read_sql(queryEmployees, DB_NW_conn)
# ----> 5 employeesAW_df = pd.read_sql(queryEmployees, DB_AW_conn)
#       8 queryTerritory= "SELECT * FROM EmployeeTerritories"
#       9 territoryNW_DF= pd.read_sql(queryTerritory, DB_NW_conn)
#
# NameError: name 'DB_AW_conn' is not defined

# %% [markdown]
# load employee into datawarehouse

# %%
def insert_into_employees_territories(merged_df, export_conn):
    try:
        export_cursor = export_conn.cursor()

        create_table_query = """
        IF NOT EXISTS (SELECT * FROM sysobjects WHERE name='Employees_Territories' AND xtype='U')
        CREATE TABLE Employees_Territories (
            EmployeeID INT,
            LastName NVARCHAR(255),
            FirstName NVARCHAR(255),
            Title NVARCHAR(255),
            TitleOfCourtesy NVARCHAR(255),
            BirthDate DATETIME,
            HireDate DATETIME,
            Address NVARCHAR(255),
            City NVARCHAR(255),
            Region NVARCHAR(255),
            PostalCode NVARCHAR(20),
            Country NVARCHAR(50),
            HomePhone NVARCHAR(25),
            Extension NVARCHAR(4),
            Photo IMAGE,
            Notes NVARCHAR(MAX),
            ReportsTo INT,
            PhotoPath NVARCHAR(255),
            TerritoryID NVARCHAR(20),
            TerritoryDescription NVARCHAR(255),
            RegionID INT
        )
        """
        export_cursor.execute(create_table_query)
        
        for index, row in merged_df.iterrows():
            try:
                query = f"""
                INSERT INTO Employees_Territories (EmployeeID, LastName, FirstName, Title, TitleOfCourtesy, BirthDate, HireDate, Address, City, Region, PostalCode, Country, HomePhone, Extension, Photo, Notes, ReportsTo, PhotoPath, TerritoryID, TerritoryDescription, RegionID)
                VALUES (
                    {row['EmployeeID'] if row['EmployeeID'] is not None else 'NULL'}, 
                    '{str(row['LastName']).replace("'", "''") if row['LastName'] is not None else 'NULL'}',
                    '{str(row['FirstName']).replace("'", "''") if row['FirstName'] is not None else 'NULL'}',
                    '{str(row['Title']).replace("'", "''") if row['Title'] is not None else 'NULL'}',
                    '{str(row['TitleOfCourtesy']).replace("'", "''") if row['TitleOfCourtesy'] is not None else 'NULL'}',
                    '{row['BirthDate']}' if row['BirthDate'] is not None else 'NULL',
                    '{row['HireDate']}' if row['HireDate'] is not None else 'NULL',
                    '{str(row['Address']).replace("'", "''") if row['Address'] is not None else 'NULL'}',
                    '{str(row['City']).replace("'", "''") if row['City'] is not None else 'NULL'}',
                    '{str(row['Region']).replace("'", "''") if row['Region'] is not None else 'NULL'}',
                    '{str(row['PostalCode']).replace("'", "''") if row['PostalCode'] is not None else 'NULL'}',
                    '{str(row['Country']).replace("'", "''") if row['Country'] is not None else 'NULL'}',
                    '{str(row['HomePhone']).replace("'", "''") if row['HomePhone'] is not None else 'NULL'}',
                    '{str(row['Extension']).replace("'", "''") if row['Extension'] is not None else 'NULL'}',
                    {row['Photo'] if row['Photo'] is not None else 'NULL'},
                    '{str(row['Notes']).replace("'", "''") if row['Notes'] is not None else 'NULL'}',
                    {row['ReportsTo'] if row['ReportsTo'] is not None else 'NULL'},
                    '{str(row['PhotoPath']).replace("'", "''") if row['PhotoPath'] is not None else 'NULL'}',
                    '{str(row['TerritoryID']).replace("'", "''") if row['TerritoryID'] is not None else 'NULL'}',
                    '{str(row['TerritoryDescription']).replace("'", "''") if row['TerritoryDescription'] is not None else 'NULL'}',
                    {row['RegionID'] if row['RegionID'] is not None else 'NULL'}
                )
                """
                export_cursor.execute(query)
            except pyodbc.Error as e:
                print("Error:", e)
                print("Query:", query)

        export_conn.commit()
    except pyodbc.Error as e:
        print("Error:", e)
    finally:
        export_cursor.close()

# Insert the merged DataFrame into the data warehouse
insert_into_employees_territories(merged_df, export_conn)

# Close the export connection
# Out:
# Error: Attempt to use a closed connection.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 73
#      70         export_cursor.close()
#      72 # Insert the merged DataFrame into the data warehouse
# ---> 73 insert_into_employees_territories(merged_df, export_conn)
#      75 # Close the export connection
#
# Cell In[18], line 70, in insert_into_employees_territories(merged_df, export_conn)
#      68     print("Error:", e)
#      69 finally:
# ---> 70     export_cursor.close()
#
# UnboundLocalError: cannot access local variable 'export_cursor' where it is not associated with a value

# %% [markdown]
# Person.Person and Person.adres  table from AW MERGED

# %%
# QUery_Person = "SELECT * FROM Person.Person"
# Query_PERsonADdres= "SELECT * FROM Person.Address"
# PAdress_df = pd.read_sql(Query_PERsonADdres, DB_AW_conn)


# # Execute the query and load data into a Pandas DataFrame
# Person_df = pd.read_sql(QUery_Person, DB_AW_conn)

# # Close the database connection

# # Now you have the Product table in a Pandas DataFrame
# Person_df
# # PAdress_df
# # merged_df = pd.merge(Person_df, PAdress_df, on='AddressID', how='inner')
